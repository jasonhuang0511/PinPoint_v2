# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

# %matplotlib inline

# %%
file_path_in_sample='..\\pattern_technical_indicator\\'
file_path_out_of_sample='..\\pattern_technical_indicator_out_of_sample\\'

for file_name in os.listdir(file_path_in_sample):
    in_sample_data=pd.read_csv(file_path_in_sample+file_name,index_col=0)
    in_sample_date=in_sample_data.index[-1]
    print(file_name+'         '+in_sample_date+'       '+str(len(in_sample_data.columns)))
# Out:
# factor_20220921_155700.csv         2021-09-15       41
# factor_20220921_163006.csv         2021-09-15       8
# factor_20220921_164013.csv         2021-09-15       32
# factor_20220921_165714.csv         2021-09-15       53
# factor_20220921_171903.csv         2021-09-15       158
# factor_20220921_172557.csv         2022-08-15       14

# %%
file_name='factor_20220921_165714.csv'

in_sample_data=pd.read_csv(file_path_in_sample+file_name,index_col=0)
in_sample_date=in_sample_data.index[-1]
in_sample_date
# Out:
# '2021-09-15'

# %%
data=pd.read_csv(file_path_out_of_sample+file_name,index_col=0)
data.index=[datetime.datetime.strptime(x,"%Y-%m-%d") for x in data.index]
index1=np.where(data.index==in_sample_date)[0][0]

d1=data.iloc[:index1,]
d2=data.iloc[index1:-100,]

indicator=pd.DataFrame()
for i in range(len(data.columns)):
    indicator.loc[i,'Factor']=data.columns[i]
    indicator.loc[i,'Ret_in_sample']=d1.iloc[:,i].diff().mean()*252
    indicator.loc[i,'IR_in_sample']=d1.iloc[:,i].diff().mean()/d1.iloc[:,i].diff().std()*15.8
    indicator.loc[i,'MDD_in_sample']=np.min((d1.iloc[:,i]/d1.iloc[:,i].cummax()-1))
    
    indicator.loc[i,'Ret_out_of_sample']=d2.iloc[:,i].diff().mean()*252
    indicator.loc[i,'IR_out_of_sample']=d2.iloc[:,i].diff().mean()/d2.iloc[:,i].diff().std()*15.8
    indicator.loc[i,'MDD_out_of_sample']=np.min((d2.iloc[:,i]/d2.iloc[:,i].cummax()-1))

# %%
indicator.index=indicator['Factor']
indicator=indicator.iloc[:,1:]
indicator=indicator.drop_duplicates().reset_index()
indicator=indicator.sort_values('IR_in_sample').reset_index(drop=True)
indicator
# Out:
#                                                Factor  Ret_in_sample  \
# 0   both5(shlsNmin(int_1()), neg(closehighest(), i...       0.055147
# 1   both5(shlsNmin(int_1()), everpositive(lownewlo...       0.040209
# 2   both5(shlsNmin(int_1()), everpositive(crosssta...       0.041193
# 3   both5(shlsNmin(int_1()), everpositive(crosssta...       0.041198
# 4   both5(shlsNmin(int_1()), shortupshadowN(float_...       0.041198
# 5   both5(shlsNmin(int_1()), everpositive(crosssta...       0.041198
# 6   both5(shlsNmin(int_1()), everpositive(crosssta...       0.041201
# 7   both5(shlsNmin(int_1()), everpositive(crosssta...       0.041227
# 8   both5(shlsNmin(int_1()), longdownshadowN(float...       0.047529
# 9   both5(shlsNmin(int_1()), everpositive(greenKN(...       0.047445
# 10  both5(shortdownshadowN(floatsub1(float_015()),...       0.081866
# 11  both5(lag(everpositive(closejumplow(), int_4()...       0.058976
# 12  both5(shlsNmin(int_1()), everpositive(openlowe...       0.049666
# 13  both5(shlsNmin(int_1()), everpositive(shortups...       0.053856
# 14  both5(shlsNmin(int_1()), shortupshadowN(float_...       0.040999
# 15  both5(shlsNmin(int_1()), everpositive(crosssta...       0.035929
# 16  both5(shortdownshadowN(floatsub1(float_03()), ...       0.084468
# 17  both5(shlsNmin(int_1()), everpositive(greenKN(...       0.036151
# 18  both5(shlsNmin(int_1()), everpositive(shortdow...       0.044288
#
#     IR_in_sample  MDD_in_sample  Ret_out_of_sample  IR_out_of_sample  \
# 0       2.478339      -0.008079           0.015169          0.392809
# 1       2.479340      -0.006869           0.029272          1.150897
# 2       2.486111      -0.005299           0.027157          0.992529
# 3       2.486458      -0.005299           0.027157          0.992529
# 4       2.486458      -0.005299           0.026187          0.945999
# 5       2.486459      -0.005299           0.027157          0.992529
# 6       2.486616      -0.005299           0.027157          0.992529
# 7       2.488276      -0.005298           0.027157          0.992529
# 8       2.497039      -0.008306           0.026530          0.903468
# 9       2.497281      -0.007880           0.017643          0.629893
# 10      2.497552      -0.010377           0.039877          0.645255
# 11      2.501575      -0.007752           0.039770          1.029527
# 12      2.515094      -0.008451           0.002324          0.065282
# 13      2.525894      -0.009810          -0.003815         -0.104205
# 14      2.536389      -0.005295           0.020445          0.807254
# 15      2.555125      -0.008193           0.016054          0.652262
# 16      2.602014      -0.010332           0.043688          0.715851
# 17      2.608076      -0.004336           0.022077          0.983408
# 18      2.751473      -0.004735           0.021270          0.773754
#
#     MDD_out_of_sample
# 0           -0.021160
# 1           -0.009570
# 2           -0.015204
# 3           -0.015204
# 4           -0.015211
# 5           -0.015204
# 6           -0.015204
# 7           -0.015203
# 8           -0.014387
# 9           -0.017016
# 10          -0.022829
# 11          -0.009440
# 12          -0.019141
# 13          -0.023710
# 14          -0.013789
# 15          -0.013377
# 16          -0.022087
# 17          -0.009891
# 18          -0.016433

# %%
plt.rcParams['figure.figsize'] = [20,10]
sns.lineplot(data=data.loc[:,indicator['Factor'][:]])
plt.axvline(x=datetime.datetime.strptime(in_sample_date,"%Y-%m-%d"),color='r')
plt.title('all')
# Out:
# Text(0.5, 1.0, 'all')
